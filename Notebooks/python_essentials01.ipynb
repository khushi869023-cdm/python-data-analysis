# %% [markdown]
# ### Python programming fundamentals

# %% [markdown]
# - #### Arithmetic Operations

# %%
2+3 #Addition
5-2 #Subtraction
4*2 #Multiplication
8/4 #Division
7//3 #Floor Division
9%4 #Modulus
2**3 #Exponentiation
# Out:
# 8

# %% [markdown]
# ![WhatsApp Image 2026-01-31 at 12.22.04 PM.jpeg](<attachment:WhatsApp Image 2026-01-31 at 12.22.04 PM.jpeg>)

# %% [markdown]
# #### Solving a multi-step problem

# %%
# A grocery store sells ice_bag for

# %% [markdown]
# #### Concatenation of strings
# Two or more strings can be joined or concatenated using + operator.
# " " empty adds space character between words.

# %%
# Concatenation in string 
full_name = "Khushi"
greeting = "Hello," + full_name + "!"
print(greeting)
print (greeting + " " + full_name + "!")
print (greeting * 3)
print (greeting + full_name)
# Out:
# Hello,Khushi!
# Hello,Khushi! Khushi!
# Hello,Khushi!Hello,Khushi!Hello,Khushi!
# Hello,Khushi!Khushi

# %% [markdown]
# Sting in py. has many Built-in methods to manipulate them.

# %%
today = "Monday"
(today.lower()) # Convert to lowercase
(today.upper()) # Convert to uppercase
# Out:
# 'MONDAY'

# %%
"monday".capitalize() # Capitalize the first letter
# Out:
# 'Monday'

# %%
"monday".replace("mon","tue") # Replace substring
# Out:
# 'tueday'

# %%
"Sun,Mon,Tue,Wed,Thu,Fri,Sat".split(",") # Split string into list 
  
a_long_time = "    to wait   "
a_long_time.strip() # Remove leading and trailing whitespace
# Out:
# 'to wait'

# %% [markdown]
# #### .format ??

# %%
# Input Variables 
cost_of_ice_bag = 1.25
profit_margin = .2
number_of_bags = 500 

# Template for output message 
output_template = """If a grocery store sells ice bags at $ {} per bag , with a profit margin of {} % , then the total profit it makes by selling {} ice bags is $ {}"""
print (output_template)
# Out:
# If a grocery store sells ice bags at $ {} per bag , with a profit margin of {} % , then the total profit it makes by selling {} ice bags is $ {}

# %%
# Inserting values into the template
total_profit = number_of_bags * cost_of_ice_bag * profit_margin 
output_message = output_template.format(cost_of_ice_bag, profit_margin*100, number_of_bags, total_profit)
print (output_message)
# Out:
# If a grocery store sells ice bags at $ 1.25 per bag , with a profit margin of 20.0 % , then the total profit it makes by selling 500 ice bags is $ 125.0

# %% [markdown]
# the placeholders {} in the output_template string are replaced with the arguments provided to the .format method

# %% [markdown]
# 2. String concatenation operator + to combine strings using str function.

# %%
cost_of_ice_bag = 1.25
profit_margin = .2
number_of_bags = 500
total_profit = cost_of_ice_bag * profit_margin * number_of_bags
"If a grocery store sells ice bags at $ " + str(cost_of_ice_bag) + " with a profit margin of " + str(profit_margin*100) + " % , then the total profit it makes by selling " + str(number_of_bags) + " ice bags is $ " + str(total_profit) # She sells ice bags at $1.25 per bag with a profit margin of 20% . If she sells 500 ice bags , what is her total profit?
# Out:
# 'If a grocery store sells ice bags at $ 1.25 with a profit margin of 20.0 % , then the total profit it makes by selling 500 ice bags is $ 125.0'

# %%
str(23)
# Out:
# '23'

# %%
first_name = "Khushi"

# %%
first_name == "Arora"
# Out:
# False

# %%
first_name == "Khushi"
# Out:
# True

# %%
first_name != "Riddhi"
# Out:
# True

# %% [markdown]
# #### List

# %%
fruits = ["apple", "banana", "cherry"]

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
type(fruits)
# Out:
# list

# %%
# List can consist of different data types   
a_list = [23, 'hello' , 3.14, True]

# %% [markdown]
# #### Length of str. or list

# %%
len(a_list)
# Out:
# 4

# %%
a_list[1] # Accessing element at index 1
# Out:
# 'hello'

# %% [markdown]
# - A new value can be added to the end of a list using the append method

# %%
a_list.append("new item") # Adding new item to the list
print(a_list)
# Out:
# [23, 'hello', 3.14, True, 'new item']

# %% [markdown]
# - A new value also can be inserted at specific index using insert method

# %%
a_list.insert(2, "inserted item") # Inserting item at index 2
print(a_list)
# Out:
# [23, 'hello', 'inserted item', 3.14, True, 'new item']

# %% [markdown]
# - Remove a value from the list using remove method.

# %%
a_list.remove(3.14) # Removing item with value 3.14
print(a_list)
# Out:
# [23, 'hello', 'inserted item', True, 'new item']

# %% [markdown]
# - To remove an element from specific index , use pop method

# %%
a_list.pop(0) # Removing item at index 0
print(a_list)
# Out:
# ['hello', 'inserted item', True, 'new item']

# %% [markdown]
# - Test whether a list contains value using in operator

# %%
'hello' in a_list  # Check if 'hello' is in the list
# Out:
# True

# %% [markdown]
# ### Concatenation
# - To combine two or more lists , use the + operator

# %%
one_more_list = a_list + [42, "world", False]
print(one_more_list)
# Out:
# ['hello', 'inserted item', True, 'new item', 42, 'world', False]

# %% [markdown]
# - To create a copy of list , use .copy method

# %%
one_more_list.copy()    
print(one_more_list)
# Out:
# ['hello', 'inserted item', True, 'new item', 42, 'world', False]

# %% [markdown]
# #### Tuples
# These are immutable thus they cannot be modified once they are created.
# - tuples ()
# - list []

# %%
fruits = ('apple', 'banana', 'cherry')

# %%
# Check no. of elements in tuple
len(fruits)
# Out:
# 3

# %%
# Get an element (positive index)
fruits[0]
# Out:
# 'apple'

# %%
# Get an element (negative index)
fruits[-2]
# Out:
# 'banana'

# %%
a_tuple = [23, "hello", False , None , 23 , 37  ]
help(a_tuple.count)
# Out:
# Help on built-in function count:
#
# count(value, /) method of builtins.list instance
#     Return number of occurrences of value.

# %% [markdown]
# - Built-in methods for tuples : .count and .index

# %%
# help # to check the documentation function 
# ?a_tuple.index
# Out:
# Signature: a_tuple.index(value, start=0, stop=9223372036854775807, /)
# Docstring:
# Return first index of value.
#
# Raises ValueError if the value is not present.
# Type:      builtin_function_or_method

# %% [markdown]
# Within Jupyter notebooks if the code cell starts with ? or help and type the name of a function or method, upon execution you will see the documentation for the method/function in a window

# %% [markdown]
# #### Dictionary
# An unodered collection of values . There is no order how we access those values.
# Each item in dict. is stored as key:value pairs
# - Key is used to retrieve values from dict.
# - type : dict
# - represented in {} <br>
# Dictionary stores many pieces of information eg details about a person , in a single variable.

# %%
person1 = {
    'name': 'Khushi' ,
    'sex' : 'Female' ,
    'age': 23 ,
    'married' : False 
}

# %%
person1
# Out:
# {'name': 'Khushi', 'sex': 'Female', 'age': 23, 'married': False}

# %% [markdown]
# Dictionary can also be created using dict functions

# %%
person2 = dict(name= 'Tane' , sex='Female', age = 27)

# %%
type(person1)
# Out:
# dict

# %% [markdown]
# To access the value in dictionary we do it by providing the key. So we need to know what keys do wewant to access using [ ]

# %%
person1 ['name']
# Out:
# 'Khushi'

# %% [markdown]
# If the key isn't present in the dictionary , then a KeyError is returned , to avoid this .get method is used

# %%
person1.get("name")
# Out:
# 'Khushi'

# %% [markdown]
# The get method also accepts a default value which is returned if the key is not present in the dictionary
# e.g : "address" ; not present returns 'unknown' if -
# person1.get("address" , "unknown")

# %%
person1.get('address','unknown')
# Out:
# 'unknown'

# %%
'name' in  person1 # Checks whether a key is present or not
# Out:
# True

# %%
person1['address'] = '1,penny lane '
print(person1)
# Out:
# {'name': 'Khushi', 'sex': 'Female', 'age': 23, 'married': False, 'address': '1,penny lane '}

# %% [markdown]
# ### Methos in dictionary
# - keys()
# - values()
# - items()
# - .items()[index]
